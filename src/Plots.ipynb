# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import scatter_matrix
import matplotlib.dates as mdates
import matplotlib.ticker as mtick
import matplotlib as mpl
mpl.rcParams.update({'font.size': 14})

# %%
#histogram of work times

# %%
test_water_df = pd.read_pickle('/Users/mwirvine/Galvanize/dsi-immersive/Capstone-EngageMob-Data/test_water_df.pkl')
test_slick_df = pd.read_pickle('/Users/mwirvine/Galvanize/dsi-immersive/Capstone-EngageMob-Data/test_slick_df.pkl')
water_df = pd.read_pickle('/Users/mwirvine/Galvanize/dsi-immersive/Capstone-EngageMob-Data/water_df.pkl')
slick_df = pd.read_pickle('/Users/mwirvine/Galvanize/dsi-immersive/Capstone-EngageMob-Data/slick_df.pkl')
job_df = pd.read_pickle('/Users/mwirvine/Galvanize/dsi-immersive/Capstone-EngageMob-Data/job_df.pkl')

# %%
fig1 = plt.figure(figsize = (20, 8))
ax1 = fig1.add_subplot(121)
ax1.hist(water_df['workTime'], bins=50)
ax1.set_xlabel('Time (Hrs)')
ax1.set_ylabel('Frequency')
ax1.set_title('Water Job Work Time')
ax1.set_xlim(0,5)

ax2 = fig1.add_subplot(122)
ax2.hist(slick_df['workTime'], bins=50)
ax2.set_xlabel('Time (Hrs)')
ax2.set_ylabel('Frequency')
ax2.set_title('Slickline Job Work Time')
ax2.set_xlim(0,8)
plt.savefig('/Users/mwirvine/Galvanize/dsi-immersive/Capstone-Job-Time-Predictor/imgs/work_time_dist.png');

# %%
fig2 = plt.figure(figsize = (12,12))

ax1 = fig2.add_subplot(111)
ax1.scatter(test_slick_df['workTime_pred_Random Forest'], test_slick_df['workTime'])
ax1.set_xlabel('Predicted Work Time')
ax1.set_ylabel('Actual Work Time')
ax1.set_title('Slickline Jobs - Random Forest - Predicted vs Actual Work Time')

plt.savefig('/Users/mwirvine/Galvanize/dsi-immersive/Capstone-Job-Time-Predictor/imgs/slick_pred_v_actual.png');

# %%
fig3 = plt.figure(figsize = (15,10))
ax1 = fig3.add_subplot(111)
ax1.scatter(test_slick_df['workTime_pred_Random Forest'], test_slick_df['rf_residuals'])
ax1.set_xlabel('Predicted Work Time')
ax1.set_ylabel('Residuals')
ax1.set_title('Slickline Jobs - Random Forest - Residuals Plot')
plt.savefig('/Users/mwirvine/Galvanize/dsi-immersive/Capstone-Job-Time-Predictor/imgs/rf_residual_plot.png');
